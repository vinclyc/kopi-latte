# %% [markdown]
# ## Classifying places into Kopi (coffee shops) or Latte (cafes) places
#
# ### Import packages & load data

# %%
import pandas as pd
import pathlib
import os

# Change working directory to parent folder
os.chdir(pathlib.Path().resolve().parents[0])

# %%
places_df = pd.read_csv('data/raw/places.csv', index_col=0)
places_df.head()
# Out:
#   business_status                                  formatted_address  \
# 0     OPERATIONAL                                   Singapore 000000
# 1     OPERATIONAL  1 Fifth Ave., #01-04 Guthrie House, Singapore ...
# 2     OPERATIONAL             18 Toh Yi Dr, #01-97, Singapore 590018
# 3     OPERATIONAL         262 Serangoon Central Dr, Singapore 550262
# 4     OPERATIONAL               308 Clementi Ave 4, Singapore 120308
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                   icon_mask_base_uri  \
# ...

# %%
reviews_df = pd.read_csv('data/raw/reviews.csv', index_col=0)
reviews_df.head()
# Out:
#    author_name                                         author_url language  \
# 0     Joey Lim  https://www.google.com/maps/contrib/1031728361...       en
# 1   Timothy TM  https://www.google.com/maps/contrib/1168978263...       en
# 2   Mingli Lin  https://www.google.com/maps/contrib/1064214574...       en
# 3  Kedar Tembe  https://www.google.com/maps/contrib/1105818100...       en
# 4       Maggie  https://www.google.com/maps/contrib/1034645174...       en
#
#                                    profile_photo_url  rating  \
# 0  https://lh3.googleusercontent.com/a/AItbvmmh1i...       5
# 1  https://lh3.googleusercontent.com/a-/AFdZucqii...       4
# 2  https://lh3.googleusercontent.com/a-/AFdZuco-M...       4
# 3  https://lh3.googleusercontent.com/a/AItbvmlJai...       3
# 4  https://lh3.googleusercontent.com/a-/AFdZucrVQ...       3
#
#   relative_time_description  \
# 0              5 months ago
# 1              3 months ago
# 2              6 months ago
# ...

# %% [markdown]
# ## Using Place Names to classify
