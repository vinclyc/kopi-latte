# %%
import googlemaps
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
places_api_key = os.getenv("PLACES_API_KEY")
onemap_email = os.getenv("ONEMAP_ACCOUNT_EMAIL")
onemap_pass = os.getenv("ONEMAP_ACCOUNT_PASSWORD")

# %%
onemap_pass
# Out:
# '&bD|jCY[>+jD,mm&[m2P'

# %%
gmaps = googlemaps.Client(key=places_api_key)

# %%
# Geocoding an address
response = gmaps.places(query='cafe in bishan')

# %%
results_json = response.get('results')

# %%
response_2 = gmaps.places(page_token=response.get('next_page_token'))

# %%
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAHq90mUgy5wkKJp4sHI4MYiebGnO-DacmBne3svAlC9x6R_TIr8sM_pBIgnTNnM4A3XZlmL68Yp6YQNPFoJXSkLi2IIHVClEiRK_g6Cek2AGTenUhzk1IZHdn31KRSzQXw3GYWNIq97aBgnnNcYQNB9sptb7zyZAwk3fR7FgRLh3NBBzYTVa3AZMlQMm4gMKnpCKIiZXEJrcJlsxRV3uP6CfAWiSphDBoei0RkIebpWEGLRmFugYvBhK3TE-Y2BwurRSELDfFB2io2Se4RNyTga0qgOuGm5CWYLwH_KlV8mmQedFxmI0GwvGo5DkzE4R9ahasLO1ZT_q17kIKinqEXDfGThrqwQ1IDzd7DmqwgQEs9FYwQYoPtxgqm3auRvluQ4YXFZwvASCtZ',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': '5 Bishan Street 14, #03-01, Singapore 579783',
#    'geometry': {'location': {'lat': 1.3555789, 'lng': 103.8513296},
#     'viewport': {'northeast': {'lat': 1.357019979892722,
#       'lng': 103.8527190298927},
#      'southwest': {'lat': 1.354320320107278, 'lng': 103.8500193701073}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#    'icon_background_color': '#FF9E67',
# ...

# %%
pd.json_normalize(results_json).columns
# Out:
# Index(['business_status', 'formatted_address', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'price_level',
#        'rating', 'reference', 'types', 'user_ratings_total',
#        'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'opening_hours.open_now', 'plus_code.compound_code',
#        'plus_code.global_code'],
#       dtype='object')

# %%
response_3 = googlemaps.places.place(gmaps, place_id = 'ChIJ12hGgW4Z2jERRazfp-IeLHA')

# %%
response_3
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': '#01-408 Block',
#     'short_name': '#01-408 Block',
#     'types': ['subpremise']},
#    {'long_name': '505d', 'short_name': '505d', 'types': ['premise']},
#    {'long_name': 'Bishan Street 11',
#     'short_name': 'Bishan Street 11',
#     'types': ['route']},
#    {'long_name': 'Bishan',
#     'short_name': 'Bishan',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Singapore',
#     'short_name': 'Singapore',
#     'types': ['locality', 'political']},
#    {'long_name': 'Singapore',
#     'short_name': 'SG',
#     'types': ['country', 'political']},
#    {'long_name': '574505', 'short_name': '574505', 'types': ['postal_code']}],
#   'adr_address': '<span class="street-address">Bishan Street 11</span>, #01-408 Block 505d, <span class="country-name">Singapore</span> <span class="postal-code">574505</span>',
#   'business_status': 'OPERATIONAL',
# ...

# %%
pd.DataFrame(response.get('result'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\admin\Documents\GitHub\kopi-latte\notebooks\test.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/GitHub/kopi-latte/notebooks/test.ipynb#ch0000012?line=0'>1</a> pd.DataFrame(response.get('result'))
#
# File c:\Users\admin\Documents\GitHub\kopi-latte\env\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
import pandas as pd
pd.read_json(response.get('result'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\admin\Documents\GitHub\kopi-latte\notebooks\test.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/GitHub/kopi-latte/notebooks/test.ipynb#ch0000011?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Documents/GitHub/kopi-latte/notebooks/test.ipynb#ch0000011?line=1'>2</a> pd.read_json(response.get('result'))
#
# File c:\Users\admin\Documents\GitHub\kopi-latte\env\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# ...

# %%
response
# Out:
# {'html_attributions': [],
#  'result': {'address_components': [{'long_name': 'Singapore',
#     'short_name': 'SG',
#     'types': ['country', 'political']},
#    {'long_name': 'Ang Mo Kio',
#     'short_name': 'Ang Mo Kio',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Singapore',
#     'short_name': 'Singapore',
#     'types': ['locality', 'political']},
#    {'long_name': '787494', 'short_name': '787494', 'types': ['postal_code']}],
#   'adr_address': '50 Tagore Lane #B1-02 Entrepreneur Centre, <span class="country-name">Singapore</span> <span class="postal-code">787494</span>',
#   'business_status': 'OPERATIONAL',
#   'formatted_address': '50 Tagore Lane #B1-02 Entrepreneur Centre, Singapore 787494',
#   'formatted_phone_number': '6554 7080',
#   'geometry': {'location': {'lat': 1.3838043, 'lng': 103.828333},
#    'viewport': {'northeast': {'lat': 1.385243730291502,
#      'lng': 103.8297630302915},
# ...
